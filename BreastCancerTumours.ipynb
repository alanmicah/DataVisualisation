# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
cancer_filepath = '/Users/micah/build/DataVisualisation/input/cancer.csv'
cancer_data = pd.read_csv(cancer_filepath, index_col='Id')
cancer_data.head()
# Out:
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# 8510824         273.9            0.10240             0.06492
# 854941          523.8            0.08983             0.03766
# 85713702        201.9            0.08600             0.05943
#
#           Concavity (mean)  Concave points (mean)  Symmetry (mean)  ...  \
# Id                                                                  ...
# ...

# %%
# Find largest value in 'Perimeter (mean)' for the first 5 rows
x = 0
for n, i in enumerate(cancer_data['Perimeter (mean)'][:5]):
  if i > x:
    x=i
max_perim = x
print(max_perim)

# Find by row id
print(cancer_data.loc['8510824', 'Radius (mean)'])
# print(cancer_data[cancer_data['8510824']])
# Out:
# 87.46
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/mambaforge/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:160, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index_class_helper.pxi:70, in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: '8510824'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 10
#       7 print(max_perim)
#       9 # Find by row id
# ---> 10 print(cancer_data.loc['8510824', 'Radius (mean)'])
#      11 # print(cancer_data[cancer_data['8510824']])
#
# ...
